# %%
import pandas as pd
df = pd.read_excel(open('/Users/ymzhang/Desktop/city_pressure1.xlsx','rb'), sheetname='Sheet0')

# %%
df.rename(columns={'full_name':'city'}, inplace=True)

# %%
df.columns
# Out:
# Index(['order_date', 'city', 'grid_id', 'grid_name', 'pressure_ratio',
#        'pressure_ratio_90', 'pressure_ratio_75', 'rider_load', 'rider_load_90',
#        'rider_load_75', 'eleme_order_cnt', 'tracking_order_cnt',
#        'completion_cnt', 'time_cost', 'overtime_cnt', 'overtime_cnt_40',
#        'cancel_order_cnt', 'fraud_cnt', 'completion_rate', 'overtime_rate',
#        'overtime_rate_40', 'cancel_rate'],
#       dtype='object')

# %%
df.completion_rate=round(df.completion_rate,2)
df.pressure_ratio=round(df.pressure_ratio,2)
df.time_cost=round(df.time_cost/60,0)
df.overtime_rate=round(df.overtime_rate,2)
df.overtime_rate_40=round(df.overtime_rate_40,2)
df.cancel_rate=round(df.cancel_rate,2)

# %%
names=['order_date','city','grid_id','pressure_ratio_90','time_cost','completion_rate','overtime_rate','overtime_rate_40','cancel_rate']
names1=['pressure_ratio_90','time_cost','completion_rate','overtime_rate','overtime_rate_40','cancel_rate']

# %%
df1=df[names]
df2=df[names1]

# %%
df3=df1.dropna()

# %%
from sklearn.ensemble import IsolationForest
import numpy as np
rng = np.random.RandomState(42)
clf=IsolationForest(max_samples=100,random_state=rng)
clf.fit(df3[names1])
df1_pred=clf.predict(df3[names1])
pred=pd.Series(df1_pred)

# %%
pred.value_counts()
# Out:
#  1    61378
# -1     6820
# dtype: int64

# %%
index = [i for i,x in enumerate(pred) if x == 1]
df4=df3.ix[index]

# %%
df5=df4.ix[((df4.pressure_ratio_90<1.5)&(df4.pressure_ratio_90>0.1)&(df4.overtime_rate<=0.5)&(df4.cancel_rate<=0.2)) ,]

# %%
df5[names1].describe()
# Out:
#        pressure_ratio_90     time_cost  completion_rate  overtime_rate  \
# count       59135.000000  59135.000000     59135.000000   59135.000000
# mean            0.430903     33.083639         0.970582       0.027172
# std             0.190098      5.879416         0.055414       0.043954
# min             0.100478     12.000000         0.290000       0.000000
# 25%             0.298701     29.000000         0.970000       0.000000
# 50%             0.389286     32.000000         0.990000       0.010000
# 75%             0.519641     36.000000         1.000000       0.030000
# max             1.495652     82.000000         1.000000       0.500000
#
#        overtime_rate_40   cancel_rate
# count      59135.000000  59135.000000
# mean           0.251131      0.001645
# std            0.164384      0.006360
# min            0.000000      0.000000
# 25%            0.120000      0.000000
# 50%            0.220000      0.000000
# 75%            0.350000      0.000000
# max            1.000000      0.180000

# %%
df5_beijing=df5.ix[(df5.city=='北京市'),]

# %%
import seaborn as sns
# %matplotlib inline

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

sns.set(style="white")
# Generate a large random dataset
d = pd.DataFrame(data=df5,columns=names1)

# Compute the correlation matrix
corr = d.corr()

# Generate a mask for the upper triangle
mask = np.zeros_like(corr, dtype=np.bool)
mask[np.triu_indices_from(mask)] = True

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(8,7))

# Generate a custom diverging colormap
cmap = sns.diverging_palette(220, 10, as_cmap=True)

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr,mask=mask,cmap=cmap)
#sns.heatmap(corr, mask=mask, cmap=cmap, vmax=.3,
#            square=True, xticklabels=5, yticklabels=5,
#            linewidths=.5, cbar_kws={"shrink": .5}, ax=ax)

# %%
corr
# Out:
#                    pressure_ratio_90  time_cost  completion_rate  \
# pressure_ratio_90           1.000000   0.721420        -0.151632
# time_cost                   0.721420   1.000000        -0.189318
# completion_rate            -0.151632  -0.189318         1.000000
# overtime_rate               0.451479   0.595975        -0.254143
# overtime_rate_40            0.725268   0.956925        -0.183219
# cancel_rate                 0.148649   0.155482        -0.250670
#
#                    overtime_rate  overtime_rate_40  cancel_rate
# pressure_ratio_90       0.451479          0.725268     0.148649
# time_cost               0.595975          0.956925     0.155482
# completion_rate        -0.254143         -0.183219    -0.250670
# overtime_rate           1.000000          0.555168     0.220877
# overtime_rate_40        0.555168          1.000000     0.153611
# cancel_rate             0.220877          0.153611     1.000000

# %%
sns.pairplot(df5_beijing[names1])

# %%
sns.pairplot(df5[names1])

# %%
from sklearn.linear_model import LinearRegression
def df5_lm_std(x):
    pressure = pd.DataFrame(df5.ix[x.index].pressure_ratio_90)
    lm = LinearRegression().fit(pressure, x)    
    threshold = np.mean(x)+1.5*np.std(x)    
    return (threshold-lm.intercept_)/lm.coef_[0]
result=df5.groupby('city').agg({'overtime_rate_40': df5_lm_std,
                         'overtime_rate': df5_lm_std,
                         'cancel_rate': df5_lm_std,
                         'time_cost': df5_lm_std})
result
# Out:
#           overtime_rate_40  overtime_rate  cancel_rate  time_cost
# city
# 三亚市               0.671518       0.871894   -89.883135   0.675396
# 东莞市               0.593522       0.676229     3.624408   0.610417
# 中山市               0.744276       0.914424     3.955809   0.729196
# 临沂市               0.745935       0.952101    14.541811   0.753093
# 义乌市               0.707816       0.800367     1.351159   0.731696
# 九江市               0.749831       0.887748    -1.434487   0.760091
# 佛山市               0.686644       0.768708     2.161168   0.673969
# 兰州市               0.775507       0.786836    -9.010448   0.752941
# 包头市               0.601943       1.184746     2.198543   0.602644
# 北京市               0.839163       1.221629     2.182913   0.847844
# 南京市               0.871201       1.201426     3.352569   0.874234
# 南宁市               0.623925       0.678608     2.159255   0.625365
# 南昌市               0.635296       0.769142   -38.315347   0.641496
# 南通市               0.747060       1.120657     2.232017   0.750149
# 台州市               0.667649       0.790644     4.161259   0.684648
# 合肥市               0.882817       1.135970     1.989555   0.886109
# 吉林市               0.516066       0.766423     1.362233   0.511041
# 呼和浩特市             0.755330       1.353854     3.231885   0.765136
# 哈尔滨市              0.684471       0.902989     2.118512   0.696410
# 大连市               0.971866       1.560616   -34.216662   0.974644
# 天津市               0.778730       1.107490    29.875437   0.783530
# 太原市               0.772350       0.857685     1.364647   0.782553
# 威海市               0.917703       0.953867     3.491660   0.914064
# 宁波市               0.719843       0.933125     2.503375   0.720256
# 常州市               0.620226       0.746011     1.541408   0.615845
# 广州市               0.849178       1.117758     2.128544   0.839861
# 延边朝鲜族自治州          0.688878       0.689954     1.163500   0.655151
# 徐州市               0.589536       0.664714     1.739486   0.591569
# 惠州市               0.587110       0.715239    -2.357991   0.590680
# 成都市               0.744866       1.051068     5.686084   0.743794
# ...                    ...            ...          ...        ...
# 无锡市               0.739161       0.877326     1.994644   0.734474
# 昆明市               0.614502       0.638176     1.021758   0.606548
# 沈阳市               0.796676       1.218289     3.920408   0.794148
# 济南市               0.927627       1.151143     1.515459   0.922083
# 海口市               0.772946       1.050616     4.114562   0.774680
# 淄博市               0.530189       0.609195   -14.747998   0.519312
# 深圳市               0.822174       1.195882     2.501300   0.813680
# 湖州市               0.779340       1.229631   -56.281705   0.790033
# 湛江市               0.478752       0.522029     1.847900   0.526381
# 潍坊市               0.793983       0.902217     1.338759   0.788247
# 烟台市               0.605275       0.812989     4.017909   0.607602
# 珠海市               0.862268       1.137839    21.532208   0.875339
# 盐城市               0.515426       0.571654    -1.021690   0.467548
# 石家庄市              0.599878       0.683747     2.879976   0.607756
# 绍兴市               0.599304       0.793025     2.302256   0.602510
# 绵阳市               0.377584      13.659906    -0.589141   0.401513
# 芜湖市               0.714142       1.584023    14.956859   0.718977
# 苏州市               0.688765       0.918519     3.764996   0.693053
# 西安市               0.969232       1.098200     1.866691   0.962350
# 贵阳市               0.741605       1.017633     1.560473   0.788657
# 赣州市               0.721416       0.793929     1.932809   0.738809
# 郑州市               1.015103       1.160315     2.497099   1.014396
# 重庆市               0.910030       1.047199     5.562889   0.910048
# 金华市               0.701660       0.895650     2.264970   0.707131
# 银川市               0.578913       0.823640     1.964083   0.593234
# 镇江市               0.664805       0.921576    -2.734286   0.661719
# 长春市               0.721824       1.058025     5.483088   0.717711
# 长沙市               0.850418       0.975321     2.113843   0.852156
# 青岛市               0.956589       1.260634     1.649615   0.964735
# 齐齐哈尔市             0.678850       1.385937    11.819004   0.665266
#
# [62 rows x 4 columns]

# %%
result.columns
# Out:
# Index(['overtime_rate_40', 'overtime_rate', 'cancel_rate', 'time_cost'], dtype='object')

# %%
plt.hist(result.overtime_rate_40)
# Out:
# (array([  1.,   1.,   4.,  11.,   9.,  14.,   9.,   6.,   3.,   4.]),
#  array([ 0.37758366,  0.44133563,  0.5050876 ,  0.56883958,  0.63259155,
#          0.69634352,  0.7600955 ,  0.82384747,  0.88759944,  0.95135142,
#          1.01510339]),
#  <a list of 10 Patch objects>)

# %%
df5['pressure_ratio1']=round(df5.pressure_ratio_90,1)
df5_beijing['pressure_ratio1']=round(df5_beijing.pressure_ratio_90,1)
df5['pressure_ratio1'] = df5['pressure_ratio1'].astype('category')
df5_beijing['pressure_ratio1'] = df5_beijing['pressure_ratio1'].astype('category')
# Out:
# /Users/ymzhang/anaconda/lib/python3.6/site-packages/ipykernel/__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':
# /Users/ymzhang/anaconda/lib/python3.6/site-packages/ipykernel/__main__.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   from ipykernel import kernelapp as app
# /Users/ymzhang/anaconda/lib/python3.6/site-packages/ipykernel/__main__.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   app.launch_new_instance()
# /Users/ymzhang/anaconda/lib/python3.6/site-packages/ipykernel/__main__.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
plt.subplots(figsize=(15,8))
sns.boxplot(x="pressure_ratio1", y='overtime_rate',data=df5_beijing)

# %%
plt.subplots(figsize=(15,8))
sns.boxplot(x="pressure_ratio1", y='overtime_rate_40',data=df5_beijing)

# %%
plt.subplots(figsize=(15,8))
sns.boxplot(x="pressure_ratio1", y='time_cost',data=df5_beijing)

# %%
plt.subplots(figsize=(15,8))
sns.boxplot(x="pressure_ratio1", y='cancel_rate',data=df5)
